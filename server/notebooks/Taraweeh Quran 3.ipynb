# %%
import sqlite3
import pandas as pd

def load_table(db_path: str, table_name: str):
    connection = sqlite3.connect(db_path)
    query = connection.execute(f'select * from {table_name}')

    columns = [col[0] for col in query.description]
    df = pd.DataFrame.from_records(data=query.fetchall(), columns=columns)

    connection.close()
    return df
# Out:
# /var/folders/rq/pc46dc1n5bz4f4myhxztxbhc0000gq/T/ipykernel_40848/1964259006.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
corpus_df = load_table('../../app/databases/corpus.db', 'corpus')
corpus_df.head()
# Out:
#    surah  ayah  word      ar1         ar2   ar3   ar4   ar5 pos1  pos2  pos3  \
# 0      1     1     1       بِ        سْمِ  None  None  None    P     N  None
# 1      1     1     2  ٱللَّهِ        None  None  None  None   PN  None  None
# 2      1     1     3       ٱل  رَّحْمَٰنِ  None  None  None  DET     N  None
# 3      1     1     4       ٱل    رَّحِيمِ  None  None  None  DET     N  None
# 4      1     2     1      ٱلْ      حَمْدُ  None  None  None  DET     N  None
#
#    pos4  pos5  count root_ar    lemma verb_type verf_form
# 0  None  None      2     سمو     اسْم      None      None
# 1  None  None      1     اله   اللَّه      None      None
# 2  None  None      2     رحم  رَحْمٰن      None      None
# 3  None  None      2     رحم   رَحِيم      None      None
# 4  None  None      2     حمد    حَمْد      None      None

# %%
words_df = load_table('../../app/databases/words.db', 'allwords')
words_df.head()
# Out:
#    sura  ayah  word           bn              in                      en
# 0     1     1     1         নামে     dengan nama           In (the) name
# 1     1     1     2   আল্লাহ (র)           Allah             (of) Allah,
# 2     1     1     3  পরম করুণাময়   Maha Pengasih      the Most Gracious,
# 3     1     1     4   অসীম দয়ালু  Maha Penyayang      the Most Merciful.
# 4     1     2     1  সকল প্রশংসা          pujian  All praises and thanks

# %%
words_80_percent_levels_df = load_table('../../app/databases/words80percent.db', 'levels')
words_80_percent_levels_df.head()
# Out:
#    level_num              level_title
# 0          1               This, that
# 1          2         This, that (E-A)
# 2          3               No and yes
# 3          4         No and yes (E-A)
# 4          5  Whose? pronouns endings

# %%
words_80_percent_words_df = load_table('../../app/databases/words80percent.db', 'words')
words_80_percent_words_df.head()
# Out:
#    level_num  serial_num       arabic                         english
# 0          3           1    لَا إِلهَ               (There is) no god
# 1          5           1        هُ...                             his
# 2          3           2  إِلَّا الله                    except Allah
# 3          5           2      هَا...   her, their (for broken plural)
# 4          5           3       كَ...                      your (male)

# %%
for seq, column in enumerate(corpus_df.columns):
    print(f'{seq:^2}:{column}')
# Out:
# 0 :surah
# 1 :ayah
# 2 :word
# 3 :ar1
# 4 :ar2
# 5 :ar3
# 6 :ar4
# 7 :ar5
# 8 :pos1
# 9 :pos2
# 10:pos3
# 11:pos4
# 12:pos5
# 13:count
# 14:root_ar
# 15:lemma
# 16:verb_type
# 17:verf_form

# %% [markdown]
# - tokenize arabic segments with pos
# - tokenize roots
# - given a range:
#     - Rank max appeared words
#     - Rank max appeared segments
#     - Rank max appeared roots
# - Rank simpler sentences

# %%
from dataclasses import dataclass

@dataclass
class AyahInfo:
    sura: int
    ayah: int

verses_by_ramadan_days = [
    (AyahInfo(sura=1, ayah=1), AyahInfo(sura=2, ayah=203)),
    (AyahInfo(sura=2, ayah=204), AyahInfo(sura=3, ayah=91)),
    (AyahInfo(sura=3, ayah=92), AyahInfo(sura=4, ayah=87)),
    (AyahInfo(sura=4, ayah=88), AyahInfo(sura=5, ayah=82)),
    (AyahInfo(sura=5, ayah=83), AyahInfo(sura=7, ayah=11)),
    (AyahInfo(sura=7, ayah=12), AyahInfo(sura=8, ayah=40)),
    (AyahInfo(sura=8, ayah=41), AyahInfo(sura=9, ayah=93)),
    (AyahInfo(sura=9, ayah=94), AyahInfo(sura=11, ayah=5)),
    (AyahInfo(sura=11, ayah=6), AyahInfo(sura=12, ayah=52)),
    (AyahInfo(sura=12, ayah=53), AyahInfo(sura=14, ayah=52)),
    (AyahInfo(sura=15, ayah=1), AyahInfo(sura=16, ayah=128)),
    (AyahInfo(sura=17, ayah=1), AyahInfo(sura=18, ayah=74)),
    (AyahInfo(sura=18, ayah=75), AyahInfo(sura=20, ayah=135)),
    (AyahInfo(sura=21, ayah=1), AyahInfo(sura=22, ayah=78)),
    (AyahInfo(sura=23, ayah=1), AyahInfo(sura=25, ayah=20)),
    (AyahInfo(sura=25, ayah=21), AyahInfo(sura=27, ayah=59)),
    (AyahInfo(sura=27, ayah=60), AyahInfo(sura=29, ayah=44)),
    (AyahInfo(sura=29, ayah=45), AyahInfo(sura=33, ayah=30)),
    (AyahInfo(sura=33, ayah=31), AyahInfo(sura=36, ayah=21)),
    (AyahInfo(sura=36, ayah=22), AyahInfo(sura=39, ayah=31)),
    (AyahInfo(sura=39, ayah=32), AyahInfo(sura=41, ayah=46)),
    (AyahInfo(sura=41, ayah=47), AyahInfo(sura=45, ayah=37)),
    (AyahInfo(sura=46, ayah=1), AyahInfo(sura=51, ayah=30)),
    (AyahInfo(sura=51, ayah=31), AyahInfo(sura=57, ayah=29)),
    (AyahInfo(sura=58, ayah=1), AyahInfo(sura=66, ayah=12)),
    (AyahInfo(sura=67, ayah=1), AyahInfo(sura=77, ayah=50)),
    (AyahInfo(sura=78, ayah=1), AyahInfo(sura=114, ayah=6)),
]

# %%
def get_words_for_day(day: int, df: pd.DataFrame):
    day_start_verse, day_end_verse = verses_by_ramadan_days[day]
    filter_condition = (
        ((df["surah"] == day_start_verse.sura) & (df["ayah"] >= day_start_verse.ayah))
        | ((df["surah"] == day_end_verse.sura) & (df["ayah"] <= day_end_verse.ayah))
        | ((df["surah"] > day_start_verse.sura) & (df["surah"] < day_end_verse.sura))
    )

    return df[filter_condition]

# %%
words_for_day_df = get_words_for_day(0, corpus_df)
words_for_day_df.head()
# Out:
#    surah  ayah  word      ar1         ar2   ar3   ar4   ar5 pos1  pos2  pos3  \
# 0      1     1     1       بِ        سْمِ  None  None  None    P     N  None
# 1      1     1     2  ٱللَّهِ        None  None  None  None   PN  None  None
# 2      1     1     3       ٱل  رَّحْمَٰنِ  None  None  None  DET     N  None
# 3      1     1     4       ٱل    رَّحِيمِ  None  None  None  DET     N  None
# 4      1     2     1      ٱلْ      حَمْدُ  None  None  None  DET     N  None
#
#    pos4  pos5  count root_ar    lemma verb_type verf_form
# 0  None  None      2     سمو     اسْم      None      None
# 1  None  None      1     اله   اللَّه      None      None
# 2  None  None      2     رحم  رَحْمٰن      None      None
# 3  None  None      2     رحم   رَحِيم      None      None
# 4  None  None      2     حمد    حَمْد      None      None

# %%
metadata = {
    "total_words": words_for_day_df.shape[0],
    "total_ayah": words_for_day_df.groupby(["surah", "ayah"]).size().count(),
    "unique_words": words_for_day_df.groupby(["ar1", "ar2", "ar3", "ar4", "ar5"], dropna=False)
    .size()
    .count(),
    "uinque_roots": words_for_day_df.groupby(["root_ar"]).size().count(),
    "unique_lemma": words_for_day_df.groupby(["lemma"]).size().count(),
}

print(metadata)
# Out:
# {'total_words': 3837, 'total_ayah': 210, 'unique_words': 1884, 'uinque_roots': 460, 'unique_lemma': 817}

# %%
root_value_counts = words_for_day_df['root_ar'].value_counts()
for name, frequency in root_value_counts.items():
    print(name, frequency)
# Out:
#  1413
# اله 151
# قول 101
# كون 64
# علم 61
# امن 51
# ربب 34
# كفر 34
# كتب 31
# اتي 30
# هدي 29
# انس 27
# بين 24
# وقي 24
# نزل 23
# نفس 20
# ايي 20
# سمو 20
# ظلم 19
# شيا 19
# قبل 19
# بعد 19
# رحم 19
# قوم 18
# عذب 18
# قتل 17
# ارض 17
# يوم 17
# تبع 16
# اخذ 16
# عدو 16
# كلل 15
# ولي 15
# اخر 15
# حقق 15
# عمل 15
# عند 15
# خير 14
# ذكر 13
# فرق 13
# خرج 13
# موت 13
# بني 12
# نصر 12
# مثل 12
# جعل 12
# عبد 12
# نور 11
# عهد 11
# حجج 11
# توب 11
# حرم 11
# رسل 11
# سمع 11
# صدق 11
# سجد 11
# حيي 11
# ملك 10
# حسن 10
# اكل 10
# بعض 10
# وجه 10
# حيث 9
# دعو 9
# شري 9
# قلب 9
# صلو 9
# سال 9
# رزق 9
# سلم 9
# نعم 8
# راي 8
# امر 8
# اثم 8
# جيا 8
# كسب 7
# دنو 7
# كتم 7
# شهد 7
# عدد 7
# ضلل 7
# تلو 7
# نبا 7
# زكو 7
# صوم 7
# عقل 7
# هود 7
# شدد 7
# صلح 7
# صبر 7
# غفر 7
# قلل 6
# امم 6
# حكم 6
# بشر 6
# فعل 6
# خلف 6
# بيت 6
# باس 6
# عرف 6
# قرب 6
# لعن 6
# شكر 6
# يدي 6
# بصر 6
# حبب 6
# خوف 6
# فضل 6
# ضرر 5
# جمع 5
# ادم 5
# بقر 5
# وثق 5
# سبل 5
# احد 5
# كبر 5
# ليس 5
# عجل 5
# سكن 5
# عمر 5
# غفل 5
# نظر 5
# كلم 5
# شهر 5
# شطر 5
# برر 5
# برا 5
# بدل 5
# فسد 5
# شعر 5
# غير 5
# خلق 5
# شطن 5
# مرض 5
# رجع 5
# لقي 5
# خلد 5
# شرب 4
# دخل 4
# ليل 4
# عفو 4
# جزي 4
# صحب 4
# قدر 4
# خلو 4
# فسق 4
# عون 4
# سفه 4
# هبط 4
# الم 4
# مني 4
# مول 4
# عظم 4
# سوي 4
# بغي 4
# ابو 4
# اهل 4
# غضب 4
# ثمر 4
# تمم 4
# ضرب 4
# جنن 4
# كثر 4
# رود 4
# حجر 4
# دون 4
# نذر 3
# شرك 3
# فيض 3
# طيب 3
# ودد 3
# شجر 1
# زلل 1
# فرش 1
# رهب 1
# حول 1
# خطف 1
# حذر 1
# خشع 1
# صبع 1
# رعد 1
# سوم 1
# غرق 1
# وعد 1
# ربع 1
# مدد 1
# صبا 1
# سبت 1
# خصص 1
# هون 1
# ابد 1
# حرص 1
# الف 1
# سنو 1
# زحزح 1
# سحر 1
# مرا 1
# رعي 1
# نسخ 1
# قرد 1
# حسد 1
# صفح 1
# هات 1
# برهن 1
# منع 1
# سعي 1
# خرب 1
# وسع 1
# قنت 1
# ختم 1
# غلف 1
# ايد 1
# غشو 1
# خسا 1
# نكل 1
# وعظ 1
# عوذ 1
# جهل 1
# بكر 1
# صفر 1
# فقع 1
# ثور 1
# حرث 1
# وشي 1
# درا 1
# طمع 1
# حرف 1
# حدث 1
# نقض 1
# مسس 1
# اسر 1
# قفو 1
# حشر 1

# %%
max_words_in_ayah = words_for_day_df.groupby(['surah', 'ayah'])['word'].transform('max')
words_for_day_df['max_words'] = max_words_in_ayah
words_for_day_df.head()
# Out:
# /var/folders/rq/pc46dc1n5bz4f4myhxztxbhc0000gq/T/ipykernel_40848/73927530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   words_for_day_df['max_words'] = max_words_in_ayah
#    surah  ayah  word      ar1         ar2   ar3   ar4   ar5 pos1  pos2  pos3  \
# 0      1     1     1       بِ        سْمِ  None  None  None    P     N  None
# 1      1     1     2  ٱللَّهِ        None  None  None  None   PN  None  None
# 2      1     1     3       ٱل  رَّحْمَٰنِ  None  None  None  DET     N  None
# 3      1     1     4       ٱل    رَّحِيمِ  None  None  None  DET     N  None
# 4      1     2     1      ٱلْ      حَمْدُ  None  None  None  DET     N  None
#
#    pos4  pos5  count root_ar    lemma verb_type verf_form  max_words
# 0  None  None      2     سمو     اسْم      None      None          4
# 1  None  None      1     اله   اللَّه      None      None          4
# 2  None  None      2     رحم  رَحْمٰن      None      None          4
# 3  None  None      2     رحم   رَحِيم      None      None          4
# 4  None  None      2     حمد    حَمْد      None      None          4

# %%
root_frequency = words_for_day_df['root_ar'].value_counts()
words_for_day_df['root_frequency'] = words_for_day_df['root_ar'].map(root_frequency)
words_for_day_df.head()
# Out:
# /var/folders/rq/pc46dc1n5bz4f4myhxztxbhc0000gq/T/ipykernel_40848/2522376243.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   words_for_day_df['root_frequency'] = words_for_day_df['root_ar'].map(root_frequency)
#    surah  ayah  word      ar1         ar2   ar3   ar4   ar5 pos1  pos2  pos3  \
# 0      1     1     1       بِ        سْمِ  None  None  None    P     N  None
# 1      1     1     2  ٱللَّهِ        None  None  None  None   PN  None  None
# 2      1     1     3       ٱل  رَّحْمَٰنِ  None  None  None  DET     N  None
# 3      1     1     4       ٱل    رَّحِيمِ  None  None  None  DET     N  None
# 4      1     2     1      ٱلْ      حَمْدُ  None  None  None  DET     N  None
#
#    pos4  pos5  count root_ar    lemma verb_type verf_form  max_words  \
# 0  None  None      2     سمو     اسْم      None      None          4
# 1  None  None      1     اله   اللَّه      None      None          4
# 2  None  None      2     رحم  رَحْمٰن      None      None          4
# 3  None  None      2     رحم   رَحِيم      None      None          4
# 4  None  None      2     حمد    حَمْد      None      None          4
#
#    root_frequency
# 0              20
# 1             151
# 2              19
# 3              19
# 4               2

# %%
words_for_day_df.loc[words_for_day_df.groupby(['root_ar', 'lemma'])['max_words'].idxmin()].sort_values(['root_frequency', 'root_ar'], ascending=False)
# Out:
#       surah  ayah  word       ar1       ar2   ar3   ar4   ar5  pos1  pos2  \
# 132       2    12     1    أَلَآ      None  None  None  None   ATT  None
# 71        2     6     7      أَمْ      None  None  None  None  CONJ  None
# 371       2    26    12        فَ    أَمَّا  None  None  None   REM   EXL
# 3034      2   169     5        وَ       أَن  None  None  None  CONJ   SUB
# 682       2    46     3     أَنَّ       هُم  None  None  None   ACC  PRON
# ...     ...   ...   ...       ...       ...   ...   ...   ...   ...   ...
# 3649      2   196    24     أَذًى      None  None  None  None     N  None
# 3247      2   178    23        وَ  أَدَآءٌ  None  None  None  CONJ     N
# 3243      2   178    19     أَخِي        هِ  None  None  None     N  PRON
# 536       2    34     9    أَبَىٰ      None  None  None  None     V  None
# 1612      2    95     3  أَبَدًۢا      None  None  None  None     T  None
#
#       pos3  pos4  pos5  count root_ar    lemma verb_type verf_form  max_words  \
# 132   None  None  None      1             أَلا      None      None          7
# 71    None  None  None      1              أَم      None      None         11
# 371   None  None  None      2            أَمّا      None      None         39
# 3034  None  None  None      2              أَن      None      None         11
# 682   None  None  None      2             أَنّ      None      None          8
# ...    ...   ...   ...    ...     ...      ...       ...       ...        ...
# 3649  None  None  None      1     اذي    أَذًى      None      None         73
# 3247  None  None  None      2     ادي    أَداء      None         1         37
# 3243  None  None  None      2     اخو      أَخ      None      None         37
# 536   None  None  None      1     ابي    أَبَى        b8         1         13
# 1612  None  None  None      1     ابد  أَبَدًا      None      None          9
#
#       root_frequency
# 132             1413
# 71              1413
# 371             1413
# 3034            1413
# 682             1413
# ...              ...
# 3649               1
# 3247               1
# 3243               1
# 536                1
# 1612               1
#
# [820 rows x 20 columns]

# %%
corpus_df['lemma'].dropna().count() == corpus_df['lemma'].count()
# Out:
# True

# %%
corpus_df.head(30)
# Out:
#     surah  ayah  word          ar1          ar2   ar3   ar4   ar5  pos1  pos2  \
# 0       1     1     1           بِ         سْمِ  None  None  None     P     N
# 1       1     1     2      ٱللَّهِ         None  None  None  None    PN  None
# 2       1     1     3           ٱل   رَّحْمَٰنِ  None  None  None   DET     N
# 3       1     1     4           ٱل     رَّحِيمِ  None  None  None   DET     N
# 4       1     2     1          ٱلْ       حَمْدُ  None  None  None   DET     N
# 5       1     2     2           لِ        لَّهِ  None  None  None     P    PN
# 6       1     2     3        رَبِّ         None  None  None  None     N  None
# 7       1     2     4          ٱلْ   عَٰلَمِينَ  None  None  None   DET     N
# 8       1     3     1           ٱل   رَّحْمَٰنِ  None  None  None   DET     N
# 9       1     3     2           ٱل     رَّحِيمِ  None  None  None   DET     N
# 10      1     4     1      مَٰلِكِ         None  None  None  None     N  None
# 11      1     4     2       يَوْمِ         None  None  None  None     N  None
# 12      1     4     3           ٱل       دِّينِ  None  None  None   DET     N
# 13      1     5     1     إِيَّاكَ         None  None  None  None  PRON  None
# 14      1     5     2     نَعْبُدُ         None  None  None  None     V  None
# 15      1     5     3           وَ     إِيَّاكَ  None  None  None  CONJ  PRON
# ...      ...   ...   ...      ...   ...   ...   ...   ...   ...   ...   ...
# 77321    109     5     2  أَنتُمْ  None  None  None  None  PRON  None  None
# 77325    109     6     1       لَ  كُمْ  None  None  None     P  PRON  None
# 77327    109     6     3       وَ    لِ    ىَ  None  None  CONJ     P  PRON
# 77372    112     1     2     هُوَ  None  None  None  None  PRON  None  None
# 77383    112     4     3      لَّ   هُۥ  None  None  None     P  PRON  None
#
#        pos4  pos5  count root_ar lemma verb_type verf_form
# 29     None  None      1          None      None      None
# 55     None  None      1          None      None      None
# 63     None  None      1          None      None      None
# 85     None  None      3          None      None      None
# 97     None  None      1          None      None      None
# ...     ...   ...    ...     ...   ...       ...       ...
# 77321  None  None      1          None      None      None
# 77325  None  None      2          None      None      None
# 77327  None  None      3          None      None      None
# 77372  None  None      1          None      None      None
# 77383  None  None      2          None      None      None
#
# [3307 rows x 18 columns]

# %%
# generate word parts df
# word_part, sura, ayah, word_index, part_index, pos, word_root, word_lemma, word_part_without_harakat

import pyarabic.araby as araby

word_parts_data = []

for index, row in corpus_df.iterrows():
    word_part_count = row['count']
    for word_part_index in range(word_part_count):
        word_part = row[f"ar{word_part_index+1}"]
        word_parts_data.append({
            "word_part": word_part,
            "sura": row["surah"],
            "ayah": row["ayah"],
            "word_index": row["word"],
            "part_index": word_part_index,
            "pos": row[f"pos{word_part_index+1}"],
            "word_root": row["root_ar"],
            "word_lemma": row["lemma"],
            # "verb_type": row["verb_type"],
            # "verb_form": row["verf_form"],
            "word_part_without_harakat": araby.strip_harakat(word_part)
        })

word_parts_df = pd.DataFrame(word_parts_data)
word_parts_df.head()
# Out:
#     word_part  sura  ayah  word_index  part_index  pos word_root word_lemma  \
# 0          بِ     1     1           1           0    P       سمو       اسْم
# 1        سْمِ     1     1           1           1    N       سمو       اسْم
# 2     ٱللَّهِ     1     1           2           0   PN       اله     اللَّه
# 3          ٱل     1     1           3           0  DET       رحم    رَحْمٰن
# 4  رَّحْمَٰنِ     1     1           3           1    N       رحم    رَحْمٰن
#
#   word_part_without_harakat
# 0                         ب
# 1                        سم
# 2                     ٱللّه
# 3                        ٱل
# 4                    رّحمٰن

# %%
{
    "total_word_parts": word_parts_df.shape[0],
    "unique_word_parts": word_parts_df.groupby(["word_part"]).size().count(),
    "unique_word_parts_with_grammar_context": word_parts_df.groupby(["word_part", "pos"]).size().count(),
    "unique_word_part_without_harakat": word_parts_df.groupby(["word_part_without_harakat"]).size().count(),
    "unique_word_part_without_harakat_with_grammar_context": word_parts_df.groupby(["word_part_without_harakat", "pos"]).size().count(),
    "unique_word_root": word_parts_df.groupby(["word_root"]).size().count(),
    "unique_word_lemma": word_parts_df.groupby(["word_lemma"]).size().count(),
    "unique_lemma_with_root_context": word_parts_df.groupby(["word_lemma", "word_root"]).size().count(),
}
# Out:
# {'total_word_parts': 130035,
#  'unique_word_parts': 12186,
#  'unique_word_parts_with_grammar_context': 12391,
#  'unique_word_part_without_harakat': 8703,
#  'unique_word_part_without_harakat_with_grammar_context': 9078,
#  'unique_word_root': 1652,
#  'unique_word_lemma': 4726,
#  'unique_lemma_with_root_context': 4751}
