    _, end_sura_ayah = day_verse[-1].split(" & ")[-1].split(" - ")

    start_sura, start_ayah = start_sura_ayah.split(":")
    end_sura, end_ayah = end_sura_ayah.split(":")

    return AyahInfo(int(start_sura), int(start_ayah)), AyahInfo(
        int(end_sura), int(end_ayah)
    )

# %%
import sqlite3
db_corpus_con = sqlite3.connect('../databases/corpus.db')

cursor = db_corpus_con.cursor()
corpus = cursor.execute("""
select * from corpus limit 2
""").fetchall()
cursor.close()

print(corpus)
# Out:
# [(1, 1, 1, 'بِ', 'سْمِ', None, None, None, 'P', 'N', None, None, None, 2, 'سمو', 'اسْم', None, None), (1, 1, 2, 'ٱللَّهِ', None, None, None, None, 'PN', None, None, None, None, 1, 'اله', 'اللَّه', None, None)]

# %%
import sqlite3
import pandas as pd

corpus_db_connection = sqlite3.connect('../databases/corpus.db')
corpus_db_query = corpus_db_connection.execute('select * from corpus')


corpus_db_columns = [col[0] for col in corpus_db_query.description]
df = pd.DataFrame.from_records(data=corpus_db_query.fetchall(), columns=corpus_db_columns)
# import os
# from pathlib import Path
# db_path = os.path.join(Path(os.path.dirname(os.path.abspath(__name__))).parent, 'databases/corpus.db')
# engine = sqlalchemy.create_engine(f'sqlite:///{db_path}')
# df = pd.read_sql_table('corpus', engine)

df.head()
# Out:
#    surah  ayah  word      ar1         ar2   ar3   ar4   ar5 pos1  pos2  pos3  \
# 0      1     1     1       بِ        سْمِ  None  None  None    P     N  None
# 1      1     1     2  ٱللَّهِ        None  None  None  None   PN  None  None
# 2      1     1     3       ٱل  رَّحْمَٰنِ  None  None  None  DET     N  None
# 3      1     1     4       ٱل    رَّحِيمِ  None  None  None  DET     N  None
# 4      1     2     1      ٱلْ      حَمْدُ  None  None  None  DET     N  None
#
#    pos4  pos5  count root_ar    lemma verb_type verf_form
# 0  None  None      2     سمو     اسْم      None      None
# 1  None  None      1     اله   اللَّه      None      None
# 2  None  None      2     رحم  رَحْمٰن      None      None
# 3  None  None      2     رحم   رَحِيم      None      None
# 4  None  None      2     حمد    حَمْد      None      None

# %%
from dataclasses import dataclass
from typing import List

@dataclass
class SurahAyah:
    surah: int
    ayah: int

@dataclass
class TaraweehRakah:
    day: int
    rakah: int
    verses: List[SurahAyah]

taraweeh_rakah_list = []

for day, day_verse in enumerate(DAY_VERSES, 1):
    for rakah_num, rakah_verse in enumerate(day_verse, 1):
        surah_ayah_str_list = rakah_verse.split(' & ')
        surah_ayah_list = []
        for surah_ayah_str in surah_ayah_str_list:
            surah_str, ayah_str = surah_ayah_str.split(' : ')
            surah_ayah_list.append(SurahAyah(int(surah_str), int(ayah_str)))

        taraweeh_rakah_list.append(TaraweehRakah(day, rakah_num, surah_ayah_list))

def get_taraweeh_rakah(surah: int, ayah: int) -> TaraweehRakah:
    pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 22
#      20 surah_ayah_list = []
#      21 for surah_ayah_str in surah_ayah_str_list:
# ---> 22     surah_str, ayah_str = surah_ayah_str.split(' : ')
#      23     surah_ayah_list.append(SurahAyah(int(surah_str), int(ayah_str)))
#      25 taraweeh_rakah_list.append(TaraweehRakah(day, rakah_num, surah_ayah_list))
#
# ValueError: not enough values to unpack (expected 2, got 1)
